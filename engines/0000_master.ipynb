# %%
# define root path of project 
from pathlib import Path
import sys

ROOT = Path("..").resolve()
sys.path.append(str(ROOT))

# %%
# load general setup
from utils.setup_general import *
# Out:
# Environment loaded

# %%
DATA
# Out:
# WindowsPath('C:/Users/javie/OneDrive - Universidad de los andes/PEG/PEG-mining-agriculture/data')
